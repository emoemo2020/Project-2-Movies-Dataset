# %% [markdown]
# # Part 3: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Importing__ the movies dataset from the CSV file "movies_complete.csv". __Inspecting__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('movies_complete.csv', parse_dates = ['release_date'])

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df['genres'].str.contains('Comedy').sum() #define the number of comedies in DF
# Out:
# 13067

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.hist(figsize = (20,12), bins = 100) #let's visualise the data using hist() function
plt.show()

# %%
 df.budget_musd.value_counts(dropna = True)
# Out:
# 5.00      286
# 10.00     258
# 20.00     243
# 2.00      241
# 15.00     226
#          ...
# 82.50       1
# 270.00      1
# 0.00        1
# 72.50       1
# 1.25        1
# Name: budget_musd, Length: 1218, dtype: int64

# %%
df.dtypes
# Out:
# id                                int64
# title                            object
# tagline                          object
# release_date             datetime64[ns]
# genres                           object
# belongs_to_collection            object
# original_language                object
# budget_musd                     float64
# revenue_musd                    float64
# production_companies             object
# production_countries             object
# vote_count                      float64
# vote_average                    float64
# popularity                      float64
# runtime                         float64
# overview                         object
# spoken_languages                 object
# poster_path                      object
# cast                             object
# cast_size                         int64
# crew_size                         int64
# director                         object
# dtype: object

# %%
df.describe(include = 'object')
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filtering__ the Dataset and __finding the best/worst n Movies__ with the following:

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Defining__ an appropriate __user-defined function__ to reuse code.

# %%
from IPython.display import HTML
pd.options.display.max_colwidth = 200

# %%
df_best = df[["poster_path", "title", "budget_musd", "revenue_musd",
              "vote_count", "vote_average", "popularity"]].copy()
df_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
df_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["ROI"] = df.revenue_musd.div(df.budget_musd)
df_best.drop('return', inplace = True, axis = 1)

# %%
df_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes", 
                   "Average_Rating", "Popularity", "Profit", "ROI"]

# %%
df_best.set_index('Title', inplace =True)

# %%
df_best.dtypes
# Out:
#                    object
# Budget            float64
# Revenue           float64
# Votes             float64
# Average_Rating    float64
# Popularity        float64
# Profit            float64
# ROI               float64
# dtype: object

# %%
subset = df_best.iloc[:5, :2]
subset
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
#
#                             Budget
# Title
# Toy Story                    30.00
# Jumanji                      65.00
# Grumpier Old Men               NaN
# Waiting to Exhale            16.00
# ...

# %%
HTML(subset.to_html(escape= False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %%
#we wll try to filter the dataframe to find films with the highest rating(vote_average).
#But resulting dataframe is not representative becuse the number of votes is too small(vote_count).
df_best.sort_values('vote_average', ascending = False)
# Out:
#                                                                                              poster_path  \
# 36996                                                                                                NaN
# 33891  <img src='http://image.tmdb.org/t/p/w185//zAb2YxgYSJTcloGTHAA9ogOVq7M.jpg' style='height:100px;'>
# 1615   <img src='http://image.tmdb.org/t/p/w185//4ifPBA4AjRQWxgVJAwSwWp6nFCa.jpg' style='height:100px;'>
# 35505  <img src='http://image.tmdb.org/t/p/w185//tdOcmIjI8sx9RZIsVgOlq4kQgJ4.jpg' style='height:100px;'>
# 25882  <img src='http://image.tmdb.org/t/p/w185//wKrH5tKdJa3y5jqAQM1eYmkXbHX.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44658  <img src='http://image.tmdb.org/t/p/w185//iJ78kYBNFIJ1HhZ2DoDf3MyN0ca.jpg' style='height:100px;'>
# 44660  <img src='http://image.tmdb.org/t/p/w185//AvfX3BwSpd3WzNgMh9UbIuKprBZ.jpg' style='height:100px;'>
# ...

# %%
#The same is with sorting the df by the ROI because there are films with small or 0 budgets.
df_best.sort_values('ROI', ascending = False)
# Out:
#                                                                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'>
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'>
# Welcome to Dongmakgol     <img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'>
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflxxk94TjmjMdotXnajh64iMad.jpg' style='height:100px;'>
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne9mfUcL8QCGxF891LWa7lZNI.jpg' style='height:100px;'>
# ...                                                                                                                    ...
# ...

# %%
df_best.query('Budget >= 5').sort_values('ROI', ascending = False)
# Out:
#                                                                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'>
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'>
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'>
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xcqSFfT6F7ZXHxowjxfG0yisT.jpg' style='height:100px;'>
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwOZXU7ddSrWE3ryOQM8sIg1sZ.jpg' style='height:100px;'>
# ...

# %%
df_best.Budget.fillna(0, inplace = True)
df_best.Votes.fillna(0, inplace = True)
df_best
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                                        ...
# ...

# %% [markdown]
# <h2>Define an appropriate user-defined function to reuse code.<h2>

# %%
def best_or_worst(n, by, ascending = False, min_bud = 0, min_votes = 0):
    
    
    df2 = df_best.query(('Budget >= @min_bud') and ('Votes >= @min_votes'))\
    [["", by]].sort_values(by = by, ascending = ascending).head(n).copy()
    
    return HTML(df2.to_html(escape=False))

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst(n = 5, by = "Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(n = 5, by = "Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
best_worst(n = 5, by = "Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst(n = 5, by = "Profit", ascending = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(n = 5, by = "ROI", min_bud = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Less Than Zero</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'></td>
#       <td>12396383.00</td>
#     </tr>
#     <tr>
#       <th>Modern Times</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'></td>
#       <td>8500000.00</td>
#     </tr>
#     <tr>
#       <th>Welcome to Dongmakgol</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'></td>
#       <td>4197476.62</td>
#     </tr>
#     <tr>
#       <th>Aquí Entre Nos</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(n = 5, by = "ROI",ascending = True, min_bud = 10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Chasing Liberty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7qzvS9QKkiDcz1K8EY9Y6ZXkUeD.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>The Cookout</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eUVEPES8KhnXbTG3G74UZfVQRb7.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Never Talk to Strangers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//IHZZLIxqF3ByEZV57RApvfh7uu.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>To Rob a Thief</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(n = 5, by = "Votes" )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(n = 5, by = "Average_Rating", min_votes = 1000)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average_Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Godfather</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iVZ3JAcAjmguGPnRNfWFOtLHOuY.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>Your Name.</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iaiy3tg9QVkDpObm1IGqmbC9A5C.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>The Shawshank Redemption</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5KCVkau1HEl7ZzfPsKAPM0sMiKc.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(n = 5, by = "Average_Rating", ascending = True, min_votes = 1000)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average_Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Boy Next Door</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iLURzDy1WMBCAxZuTZ5pbK8J14s.jpg' style='height:100px;'></td>
#       <td>4.10</td>
#     </tr>
#     <tr>
#       <th>Batman & Robin</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bsg0mrxUKyJoL4oSGP5mlhEsqp.jpg' style='height:100px;'></td>
#       <td>4.20</td>
#     </tr>
#     <tr>
#       <th>Fantastic Four</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oeMpEsjmiT9PEJbRM1Fm7TZ1dE0.jpg' style='height:100px;'></td>
#       <td>4.40</td>
#     </tr>
#     <tr>
#       <th>Ghost Rider: Spirit of Vengeance</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst(n = 5, by = "Popularity", min_votes = 1000)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filtering__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
selected_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")
selected_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
selected_actor = df.cast.str.contains("Bruce Willis")
selected_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
bruce = df.loc[selected_actor & selected_genres,["title", "poster_path", "vote_average"]]\
.sort_values(by = "vote_average", ascending = False).set_index("title")

# %%
HTML(bruce.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Fifth Element</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>Looper</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>Armageddon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>Surrogates</th>
# ...

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
selected_actor = df.cast.str.contains("Uma Thurman")

# %%
selected_director = df.director == 'Quentin Tarantino'

# %%
quentin = df.loc[selected_actor & selected_director,['title',"poster_path",'runtime','cast','director']]\
    .sort_values('runtime', ascending = True)

# %%
HTML(quentin.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>runtime</th>
#       <th>cast</th>
#       <th>director</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6667</th>
#       <td>Kill Bill: Vol. 1</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#       <td>Uma Thurman|Lucy Liu|Vivica A. Fox|Daryl Hannah|David Carradine|Michael Madsen|Julie Dreyfus|Chiaki Kuriyama|Sonny Chiba|Gordon Liu Chia-Hui|Michael Parks|Michael Bowen|Jun Kunimura|Kenji Ohba|Yuki Kazamatsuri|James Parks|Sakichi Satô|Jonathan Loughran|Yoshiyuki Morishita|Tetsuro Shimaguchi|Kazuki Kitamura|Yoji Tanaka|Sô Yamanaka|Julie Manase|Akaji Maro|Goro Daimon|Shun Sugata|Zhang Jin Zhan|Hu Xiaohui|Ambrosia Kelley|Sachiko Fujii|Shu Lan Tuan|Ai Maeda|Naomi Kusumi|Hikaru Midorikawa|高桥一生</td>
# ...

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
pixar_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
selected_dates = df.release_date.between("2010-01-01", "2015-12-31")

# %%
pixar_df = df.loc[pixar_studio & selected_dates,["title", "poster_path", "revenue_musd", "release_date"]]\
    .sort_values('revenue_musd', ascending = False)

# %%
HTML(pixar_df.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15236</th>
#       <td>Toy Story 3</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>29957</th>
#       <td>Inside Out</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>20888</th>
#       <td>Monsters University</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
selected_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")

# %%
selected_lan = df.original_language == "en"

# %%
selected_vote_av = df.vote_average >= 7.5

# %%
selected_vote_cnt = df.vote_count >= 10

# %%
high_rating_eng = df.loc[selected_genre & selected_lan & selected_vote_av & selected_vote_cnt,\
    ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]]\
    .sort_values(by = "release_date", ascending = False)\
    .set_index("title").head(20)

# %%
HTML(high_rating_eng.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>7.50</td>
#       <td>2712.00</td>
# ...

# %% [markdown]
# ## What are the most common Words in Movie Titles and Taglines?

# %%
from wordcloud import WordCloud

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df.title.dropna()
overview = df.overview.dropna()
tagline = df.tagline.dropna()

overview
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 44686          Rising and falling between a man and woman.
# 44687    An artist struggles to finish his work while a...
# 44688    When one of her hits goes wrong, a professiona...
# 44689    In a small town live two brothers, one a minis...
# 44690    50 years after decriminalisation of homosexual...
# Name: overview, Length: 43740, dtype: object

# %%
' '.join(title) # I can unite all of the string values of titles in 1 string
# Out:
# 'Toy Story Jumanji Grumpier Old Men Waiting to Exhale Father of the Bride Part II Heat Sabrina Tom and Huck Sudden Death GoldenEye The American President Dracula: Dead and Loving It Balto Nixon Cutthroat Island Casino Sense and Sensibility Four Rooms Ace Ventura: When Nature Calls Money Train Get Shorty Copycat Assassins Powder Leaving Las Vegas Othello Now and Then Persuasion The City of Lost Children Shanghai Triad Dangerous Minds Twelve Monkeys Wings of Courage Babe Carrington Dead Man Walking Across the Sea of Time It Takes Two Clueless Cry, the Beloved Country Richard III Dead Presidents Restoration Mortal Kombat To Die For How To Make An American Quilt Se7en Pocahontas When Night Is Falling The Usual Suspects Guardian Angel Mighty Aphrodite Lamerica The Big Green Georgia Kids of the Round Table Home for the Holidays The Postman The Confessional The Indian in the Cupboard Eye for an Eye Mr. Holland\'s Opus Don\'t Be a Menace to South Central While Drinking Your Juice in the Hood
# ...

# %%
titles_united = ' '.join(title)
overviews_united = ' '.join(overview)
taglines_united = ' '.join(tagline)

# %%
taglines_united
# Out:
# 'Roll the dice and unleash the excitement! Still Yelling. Still Fighting. Still Ready for Love. Friends are the people who let you be yourself... and never let you forget it. Just When His World Is Back To Normal... He\'s In For The Surprise Of His Life! A Los Angeles Crime Saga You are cordially invited to the most surprising merger of the year. The Original Bad Boys. Terror goes into overtime. No limits. No fears. No substitutes. Why can\'t the most powerful man in the world have the one thing he wants most? Part Dog. Part Wolf. All Hero. Triumphant in Victory, Bitter in Defeat. He Changed the World, But Lost a Nation. The Course Has Been Set. There Is No Turning Back. Prepare Your Weapons. Summon Your Courage. Discover the Adventure of a Lifetime! No one stays at the top forever. Lose your heart and come to your senses. Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who\'s in for the wildest New year\'s Eve of his life. New a
# ...

# %%
title_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words= 200).generate(titles_united)
title_wordcloud

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %%
tagline_wordcloud = WordCloud(background_color='white', height=2000, width=4000).generate(taglines_united)
plt.figure(figsize=(16,8))
plt.imshow(tagline_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %%
overview_wordcloud = WordCloud(background_color='white', height=2000, width=4000).generate(overviews_united)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4. Are Franchises more successful?

# %% [markdown]
# 4. __Analyzing__ the Dataset and __finding out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df['Franchise'] = df.belongs_to_collection.notna()
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df['Franchise'] = df.belongs_to_collection.isna()

# %%
df.Franchise.value_counts(normalize = True).mul(100).round(2)
# Out:
# False   90.01
# True     9.99
# Name: Franchise, dtype: float64

# %%
df.groupby('Franchise').agg({'revenue_musd':'mean'})
# Out:
#            revenue_musd
# Franchise
# False             44.74
# True             165.71

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df["ROI"] = df.revenue_musd.div(df.budget_musd)
df.groupby('Franchise').agg({'ROI':'median'})
# Out:
#            ROI
# Franchise
# False     1.62
# True      3.71

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby('Franchise').agg({'budget_musd':'mean'})
# Out:
#            budget_musd
# Franchise
# False            18.05
# True             38.32

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby('Franchise').agg({'popularity':'mean'})
# Out:
#            popularity
# Franchise
# False            2.59
# True             6.25

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby('Franchise').agg({'vote_average':'mean'})
# Out:
#            vote_average
# Franchise
# False              6.01
# True               5.96

# %% [markdown]
# ## We can calculate everything at once

# %%
df.groupby("Franchise").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean",
                            "popularity": "mean", "ROI":"median", "vote_count":"mean"})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False            18.05         44.74          6.01        2.59 1.62
# True             38.32        165.71          5.96        6.25 3.71
#
#            vote_count
# Franchise
# False           78.29
# True           412.39

# %% [markdown]
# ## 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__

# %%
df.query('Franchise')\
    .groupby('belongs_to_collection')\
    .agg({'title':'count'})\
    .sort_values('title', ascending = False)
# Out:
#                                             title
# belongs_to_collection
# The Bowery Boys                                29
# Totò Collection                                27
# James Bond Collection                          26
# Zatôichi: The Blind Swordsman                  26
# The Carry On Collection                        25
# ...                                           ...
# Göta kanal collection                           1
# Hailey Dean Mystery Collection                  1
# The Adventures of Mickey Matson Collection      1
# The 1997 Trilogy                                1
# Flesh Gordon Collection                         1
#
# [1691 rows x 1 columns]

# %% [markdown]
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df1 = df.query('Franchise')\
    .groupby('belongs_to_collection')\
    .agg({'budget_musd': ['mean', 'count']})\

df1.columns = df1.columns.map('_'.join) #getting rid of the multiindex

# %%
df1
# Out:
#                                       budget_musd_mean  budget_musd_count
# belongs_to_collection
# ... Has Fallen Collection                        65.00                  2
# 00 Schneider Filmreihe                             NaN                  0
# 08/15 Collection                                   NaN                  0
# 100 Girls Collection                               NaN                  0
# 101 Dalmatians (Animated) Collection              4.00                  1
# ...                                                ...                ...
# Сказки Чуковского                                  NaN                  0
# Чебурашка и крокодил Гена                          NaN                  0
# Что Творят мужчины! (Коллекция)                   2.00                  1
# 男はつらいよ シリーズ                                        NaN                  0
# 식객 시리즈                                             NaN                  0
#
# [1691 rows x 2 columns]

# %% [markdown]
# ## 6. Most Successful Directors

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
plt.figure(figsize = (12, 8))
df.director.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Directors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
df.groupby('director').agg({'title':'count','revenue_musd':'sum','vote_average':'mean' })\
    .sort_values(['title','revenue_musd','vote_average'], ascending = False)
# Out:
#                   title  revenue_musd  vote_average
# director
# John Ford            66         85.17          6.38
# Michael Curtiz       65         37.82          6.00
# Werner Herzog        54         24.57          6.81
# Alfred Hitchcock     53        250.11          6.64
# Woody Allen          49        993.97          6.69
# ...                 ...           ...           ...
# Yu Nakai              1          0.00           NaN
# Yulin Kuang           1          0.00           NaN
# Yuliya Solntseva      1          0.00           NaN
# Zion Myers            1          0.00           NaN
# fraser Watson         1          0.00           NaN
#
# [17349 rows x 3 columns]

# %%
df.groupby('director').agg({'title':'count'})\
    .sort_values('title', ascending = False)
# Out:
#                   title
# director
# John Ford            66
# Michael Curtiz       65
# Werner Herzog        54
# Alfred Hitchcock     53
# Woody Allen          49
# ...                 ...
# Jason Zada            1
# Jasper James          1
# Javier Aguirre        1
# Javier Balaguer       1
# 진모영                   1
#
# [17349 rows x 1 columns]

# %%
 df.groupby('director').agg({'revenue_musd':'sum'})\
    .sort_values('revenue_musd', ascending = False)
# Out:
#                   revenue_musd
# director
# Steven Spielberg       9256.62
# Peter Jackson          6528.24
# Michael Bay            6437.47
# James Cameron          5900.61
# David Yates            5334.56
# ...                        ...
# Héctor Olivera            0.00
# Hélène Fillières          0.00
# Héléna Klotz              0.00
# I. Robert Levy            0.00
# 진모영                       0.00
#
# [17349 rows x 1 columns]

# %%
plt.figure(figsize = (12, 8))
df.groupby("director").revenue_musd.sum().nlargest(20).plot(kind='bar', fontsize = 15)
plt.title("Total Revenue",fontsize = 20)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.show()

# %%
df.groupby('director').agg({'vote_average':'mean'})\
    .sort_values('vote_average', ascending = False)
# Out:
#                       vote_average
# director
# Antonis Sotiropoulos         10.00
# Brian Skeet                  10.00
# Joel Heath                   10.00
# Lukas Bossuyt                10.00
# Osman F. Seden               10.00
# ...                            ...
# Yulin Kuang                    NaN
# Yuliya Solntseva               NaN
# Zion Myers                     NaN
# fraser Watson                  NaN
# Вера Кричевская                NaN
#
# [17349 rows x 1 columns]

# %% [markdown]
# ## Most Successful Actors (Part 1)

# %%
df.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44686              Leila Hatami|Kourosh Tahami|Elham Korda
# 44687    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44688    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44689    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.set_index('id', inplace = True)

# %%
actors = df.cast.str.split("|", expand = True)

# %%
actors = actors.stack().reset_index(level = 1, drop = True).to_frame().rename(columns = {0:'Actor_name'})

# %%
actors = actors.merge(df[["title", "revenue_musd", "vote_average", "popularity"]],
                how = "left", on = 'id' )

# %%
actors.groupby('Actor_name').agg({'revenue_musd':'sum', 'vote_average':'mean', 'popularity':'mean'})\
    .sort_values('revenue_musd', ascending = False)
# Out:
#                    revenue_musd  vote_average  popularity
# Actor_name
# Stan Lee               19414.96          6.51       29.94
# Samuel L. Jackson      17109.62          6.27       11.70
# Warwick Davis          13256.03          6.29       13.09
# Frank Welker           13044.15          6.31        9.57
# John Ratzenberger      12596.13          6.48       10.96
# ...                         ...           ...         ...
# Janine Perreau             0.00          6.10        2.63
# Janine Reynaud             0.00          5.42        1.36
# Janine Souchon             0.00          6.60        1.35
# Janine Venable             0.00          4.50        4.23
# 조병만                        0.00          6.00        0.44
#
# [201501 rows x 3 columns]

# %%
plt.figure(figsize = (12, 8))
actors.Actor_name.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Actors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
Actors_agg = actors.groupby('Actor_name').agg(Total_revenue = ('revenue_musd','sum'), 
                                 Mean_rating = ('vote_average','mean'), 
                                 Avg_popularity = ('popularity','mean'),
                                Total_movies =('Actor_name', 'count') )

# %%
Actors_agg.nlargest(10, 'Total_revenue')
# Out:
#                    Total_revenue  Mean_rating  Avg_popularity  Total_movies
# Actor_name
# Stan Lee                19414.96         6.51           29.94            48
# Samuel L. Jackson       17109.62         6.27           11.70           122
# Warwick Davis           13256.03         6.29           13.09            34
# Frank Welker            13044.15         6.31            9.57           107
# John Ratzenberger       12596.13         6.48           10.96            46
# Jess Harnell            12234.61         6.44           10.92            35
# Hugo Weaving            11027.58         6.47           10.97            40
# Ian McKellen            11015.59         6.35           15.45            44
# Johnny Depp             10653.76         6.44           12.38            69
# Alan Rickman            10612.63         6.72           10.40            45

# %%
Actors_agg[Actors_agg.Total_movies >= 30].nlargest(10,'Mean_rating')
# Out:
#                    Total_revenue  Mean_rating  Avg_popularity  Total_movies
# Actor_name
# Toshirō Mifune             32.12         7.23            3.99            40
# Tatsuya Nakadai             4.34         7.19            3.19            35
# Eijirô Tôno                29.82         7.09            2.85            32
# Chishu Ryu                  0.50         7.08            1.43            50
# Martin Scorsese           800.29         7.05            3.94            45
# Werner Herzog             788.19         7.04            3.18            46
# Philip Ettington         6105.41         7.02           15.61            41
# Jean-Pierre Léaud          51.33         6.97            3.48            36
# Takashi Shimura             0.42         6.95            3.86            40
# Bert Stevens              181.01         6.90            5.10            36
